# %% [markdown]
# <a href="https://colab.research.google.com/github/Rushitha14/Rushitha/blob/main/Copy_of_notebookbd3f87ac8b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# !git clone https://github.com/Rushitha14/Rushitha.git
repo_path="/content/Rushitha"
for dirname, _, filenames in os.walk(repo_path):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Cloning into 'Rushitha'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 134.21 KiB | 2.49 MiB/s, done.
# /content/Rushitha/IMDB-Movie-Data.csv
# /content/Rushitha/README.md
# /content/Rushitha/.git/packed-refs
# /content/Rushitha/.git/config
# /content/Rushitha/.git/description
# /content/Rushitha/.git/index
# /content/Rushitha/.git/HEAD
# /content/Rushitha/.git/objects/pack/pack-6747d0f4c8958f39ebc16e336dd992964bd21c4e.pack
# /content/Rushitha/.git/objects/pack/pack-6747d0f4c8958f39ebc16e336dd992964bd21c4e.idx
# /content/Rushitha/.git/logs/HEAD
# /content/Rushitha/.git/logs/refs/remotes/origin/HEAD
# /content/Rushitha/.git/logs/refs/heads/main
# /content/Rushitha/.git/hooks/pre-receive.sample
# /content/Rushitha/.git/hooks/post-update.sample
# /content/Rushitha/.git/hooks/pre-rebase.sample
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %% [markdown]
# # Youtube Video Link : https://youtu.be/Asm2_qgBK48

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/content/Rushitha/IMDB-Movie-Data.csv')

# %% [markdown]
# # 1. Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %% [markdown]
# # 2. Check Last 10 Rows of The Dataset

# %%
data.tail(10)

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape

# %%
print('Number of Rows',data.shape[0])
print('Number of Columns',data.shape[1])
# Out:
# Number of Rows 1000
# Number of Columns 12

# %% [markdown]
# # 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()

# %% [markdown]
# # 5. Check Null Values In The Dataset

# %%
data.isnull().sum()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # 6. Drop All The Missing Values

# %%
data = data.dropna(axis=0)

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # 7. Check For Duplicate Data

# %%
dup_data=data.duplicated().any()
print("Are there any duplicated values in data?",dup_data)
# Out:
# Are there any duplicated values in data? False

# %% [markdown]
# # 8. Get Overall Statistics About The DataFrame

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %% [markdown]
# # 9. Display Title of The Movie Having Runtime >= 180 Minutes

# %%
data[data['Runtime (Minutes)']>=180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# 828                 Grindhouse
# 965              Inland Empire
# Name: Title, dtype: object

# %% [markdown]
# # 10. In Which Year There Was The Highest Voting?

# %%
import seaborn as sns
sns.barplot(x='Year',y='Votes',data=data)
plt.title("Votes By Year")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1274987675.py in <cell line: 0>()
#       1 import seaborn as sns
#       2 sns.barplot(x='Year',y='Votes',data=data)
# ----> 3 plt.title("Votes By Year")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # 11. In Which Year There Was The Highest Revenue?

# %%
sns.barplot(x='Year',y='Revenue (Millions)',data=data)
plt.title("Revenue By Year")
plt.show()

# %% [markdown]
# # 12. Find The Average Rating For Each Director

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending=False)

# %% [markdown]
# # 13. Display Top 10 Lengthy Movies Title

# %%
le =data.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']]. \
set_index('Title')

# %%
sns.barplot(le['Runtime (Minutes)'],y=le.index)
plt.title('Top 5 Lengtly Movies')
plt.show()

# %% [markdown]
# # 14. Display Number of Movies Per Year

# %%
sns.countplot(x='Year',data=data)
plt.title("Number of Movies Per Year")

# %% [markdown]
# # 15. Find Most Popular Movie Title (Higest Revenue)

# %%
data.columns

# %%
data[data['Revenue (Millions)'].max() == data['Revenue (Millions)']]['Title']

# %% [markdown]
# # 16. Display Top 10 Highest Rated Movie Titles And its Directors

# %%
top_10=data.nlargest(10,'Rating')[['Title','Rating','Director']].set_index('Title')

# %%
top_10

# %%
sns.barplot(top_10['Rating'],top_10.index)
plt.title("Display Top 10 Highest Rated Movie Titles")

# %% [markdown]
# # 17. Display Top 10 Highest Revenue Movie Titles

# %%
data.columns

# %%
data.sort_values(by='Revenue (Millions)',ascending=False).head(10)

# %%
top_10 = data.nlargest(10,'Revenue (Millions)')[['Title','Director','Revenue (Millions)']].set_index('Title')

# %%
sns.barplot(top_10['Revenue (Millions)'],top_10.index)
plt.title("Display Top 10 Highest Revenue Movie Titles")
plt.show()

# %% [markdown]
# # 18.  Find Average Rating of Movies Year-wise

# %%
data.columns

# %%
data1=data.groupby('Year')['Year','Rating'].mean().\
sort_values(by='Rating',ascending=False).set_index('Year')

# %%
data1

# %%
plt.figure(figsize=(10,5))
sns.barplot(data1.index,data1['Rating'])
plt.show()

# %% [markdown]
# # 19. Does Rating Affect The Revenue?

# %%
sns.scatterplot(x='Rating',y='Revenue (Millions)',data=data)

# %% [markdown]
# # Answer : Yes

# %% [markdown]
# # 20. Classify Movies Based on Ratings [Good,Better and Best]

# %%
data.columns

# %%
def rating(rating):
    if rating>=7.0:
        return 'Excellent'
    elif rating>=6.0:
        return 'Good'
    else:
        return 'Average'

# %%
data['rating_cat']=data['Rating'].apply(rating)

# %%
data.head(1)

# %% [markdown]
# # 21. Count Number of Action Movies

# %%
list1=[]
for value in data['Genre']:
    list1.append(value.split(','))

# %%
data['temp']=list1

# %%
genre=input("Enter Genre you want to count : ").title()
count=0
for value in data['temp']:
    if genre in value:
        count=count+1
print("Total Count is",count)
# Out:
# Enter Genre you want to count : horror
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'temp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-720143593.py in <cell line: 0>()
# ...

# %% [markdown]
# # OR

# %%
len(data[data['Genre'].str.contains('action',case=False)])

# %% [markdown]
# ## 22. Top 10 Longest Movies

# %%
data.nlargest(10, 'Runtime (Minutes)')[['Title', 'Runtime (Minutes)']]
# Out:
#                                         Title  Runtime (Minutes)
# 828                                Grindhouse                191
# 88                          The Hateful Eight                187
# 82                    The Wolf of Wall Street                180
# 311                            La vie d'Adèle                180
# 965                             Inland Empire                180
# 267                               Cloud Atlas                172
# 430                                  3 Idiots                170
# 36                               Interstellar                169
# 75   Pirates of the Caribbean: At World's End                169
# 271         The Hobbit: An Unexpected Journey                169

# %%
# @title 23. Top 10 Shortest Movies

# %%
data.nsmallest(10, 'Runtime (Minutes)')[['Title','Runtime (Minutes)']]
# Out:
#                                                  Title  Runtime (Minutes)
# 793                                Ma vie de Courgette                 66
# 42                             Don't Fuck in the Woods                 73
# 819                                 Wolves at the Door                 73
# 711                                    La tortue rouge                 80
# 949                                              Kicks                 80
# 258                                         Lights Out                 81
# 317                                    The Stakelander                 81
# 382                                               Hush                 81
# 444                                       The Thinning                 81
# 862  Alexander and the Terrible, Horrible, No Good,...                 81

# %%
genere_rating = data.groupby('Genre')['Rating'].mean().sort_values(ascending=False)
print(genere_rating)
# Out:
# Genre
# Animation,Drama,Fantasy    8.60
# Drama,Family,Music         8.50
# Drama,Western              8.40
# Animation,Drama,Romance    8.40
# Adventure,Drama,Sci-Fi     8.30
#                            ...
# Action,Fantasy,Thriller    5.20
# Sci-Fi,Thriller            5.00
# Sci-Fi                     4.95
# Comedy,Western             4.80
# Fantasy,Horror,Thriller    3.20
# Name: Rating, Length: 207, dtype: float64

# %%
data['Year'].value_counts().sort_index().plot(kind='bar', figsize=(12,5), title="Movies Released per Year")
# Out:
# <Axes: title={'center': 'Movies Released per Year'}, xlabel='Year'>

# %%
def get_top_movies(df, n):
    return df.nlargest(n, 'Rating')[['Title', 'Rating']]

n = int(input("Enter number of top movies: "))
print(get_top_movies(data, n))
# Out:
# Enter number of top movies: 3
#                Title  Rating
# 54   The Dark Knight     9.0
# 80         Inception     8.8
# 117           Dangal     8.8

# %%
def get_top_revenue_movies(df, n):
    return df.nlargest(n, 'Revenue (Millions)')[['Title', 'Revenue (Millions)']]

num = int(input("Enter No.Of Top Revenue Movies"))
print(get_top_revenue_movies(data, num))
# Out:
# Enter No.Of Top Revenue Movies3
#                                          Title  Revenue (Millions)
# 50  Star Wars: Episode VII - The Force Awakens              936.63
# 87                                      Avatar              760.51
# 85                              Jurassic World              652.18

# %%
data['Director'].value_counts().head(10)
# Out:
# Director
# Ridley Scott          8
# David Yates           6
# Paul W.S. Anderson    6
# Michael Bay           6
# M. Night Shyamalan    6
# Christopher Nolan     5
# Peter Berg            5
# Justin Lin            5
# J.J. Abrams           5
# Danny Boyle           5
# Name: count, dtype: int64

# %%
from collections import Counter
actor_list = data['Actors'].str.split(', ')
all_actors = [actor for sublist in actor_list for actor in sublist]
pd.Series(Counter(all_actors)).nlargest(10)
# Out:
# Mark Wahlberg         15
# Christian Bale        13
# Hugh Jackman          13
# Brad Pitt             13
# Michael Fassbender    12
# Tom Hardy             12
# Jake Gyllenhaal       11
# Johnny Depp           11
# Robert Downey Jr.     11
# Channing Tatum        11
# dtype: int64

# %%
data.nlargest(10, 'Revenue (Millions)')[['Title', 'Revenue (Millions)']]
# Out:
#                                           Title  Revenue (Millions)
# 50   Star Wars: Episode VII - The Force Awakens              936.63
# 87                                       Avatar              760.51
# 85                               Jurassic World              652.18
# 76                                 The Avengers              623.28
# 54                              The Dark Knight              533.32
# 12                                    Rogue One              532.17
# 119                                Finding Dory              486.29
# 94                      Avengers: Age of Ultron              458.99
# 124                       The Dark Knight Rises              448.13
# 578             The Hunger Games: Catching Fire              424.65

# %%
data[data['Revenue (Millions)'].isna()][['Title','Year']]
# Out:
#                               Title  Year
# 7                          Mindhorn  2016
# 22                   Hounds of Love  2016
# 25                  Paris pieds nus  2016
# 39                        5- 25- 77  2007
# 42          Don't Fuck in the Woods  2016
# ..                              ...   ...
# 977                   Amateur Night  2016
# 978  It's Only the End of the World  2016
# 988                         Martyrs  2008
# 995            Secret in Their Eyes  2015
# 998                    Search Party  2014
#
# [128 rows x 2 columns]

# %%
data.groupby('Year')['Runtime (Minutes)'].mean().plot(figsize=(10,5), title="Average Runtime per Year")
# Out:
# <Axes: title={'center': 'Average Runtime per Year'}, xlabel='Year'>

# %%
data[['Rating', 'Revenue (Millions)']].corr()
# Out:
#                       Rating  Revenue (Millions)
# Rating              1.000000            0.217654
# Revenue (Millions)  0.217654            1.000000

# %%
data.nlargest(10, 'Metascore')[['Title','Metascore']]
# Out:
#                      Title  Metascore
# 656                Boyhood      100.0
# 41               Moonlight       99.0
# 230        Pan's Labyrinth       98.0
# 21   Manchester by the Sea       96.0
# 111       12 Years a Slave       96.0
# 489            Ratatouille       96.0
# 509                Gravity       96.0
# 324     The Social Network       95.0
# 406       Zero Dark Thirty       95.0
# 501                  Carol       95.0

# %%
data.nlargest(10, 'Votes')[['Title','Votes']]
# Out:
#                      Title    Votes
# 54         The Dark Knight  1791916
# 80               Inception  1583625
# 124  The Dark Knight Rises  1222645
# 36            Interstellar  1047747
# 76            The Avengers  1045588
# 144       Django Unchained  1039115
# 77    Inglourious Basterds   959065
# 99            The Departed   937414
# 87                  Avatar   935408
# 64            The Prestige   913152

# %%
director_rating = data.groupby('Director')['Rating'].mean().sort_values(ascending=False).head(10)
print(director_rating)
# Out:
# Director
# Nitesh Tiwari                       8.80
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
# Naoko Yamada                        8.40
# Damien Chazelle                     8.40
# S.S. Rajamouli                      8.30
# Thomas Vinterberg                   8.30
# Name: Rating, dtype: float64

# %%
data['Rating'].plot(kind='hist', bins=20, title="Rating Distribution")
# Out:
# <Axes: title={'center': 'Rating Distribution'}, ylabel='Frequency'>

# %%
data['Runtime (Minutes)'].plot(kind='hist', bins=20, title="Runtime Distribution")
# Out:
# <Axes: title={'center': 'Runtime Distribution'}, ylabel='Frequency'>

# %%
data.plot.scatter(x='Votes', y='Rating', alpha=0.5, title="Votes vs Rating")
# Out:
# <Axes: title={'center': 'Votes vs Rating'}, xlabel='Votes', ylabel='Rating'>

# %%
data[(data['Rating'] > 8.0) & (data['Revenue (Millions)'] < 50)][['Title','Rating','Revenue (Millions)']]
# Out:
#                        Title  Rating  Revenue (Millions)
# 26   Bahubali: The Beginning     8.3                6.50
# 96             Kimi no na wa     8.6                4.68
# 117                   Dangal     8.8               11.15
# 133                 Whiplash     8.5               13.09
# 143                     Room     8.2               14.68
# 145                Ah-ga-ssi     8.1                2.01
# 192                Spotlight     8.1               44.99
# 194                  Warrior     8.2               13.65
# 197            Into the Wild     8.1               18.35
# 230          Pan's Labyrinth     8.2               37.62
# 249         The Intouchables     8.6               13.18
# 299      There Will Be Blood     8.1               40.22
# 334                     Rush     8.1               26.90
# 430                 3 Idiots     8.4                6.52
# 455                   Jagten     8.3                0.61
# ...

# %%
high_rated = data[data['Rating'] >= 8.0]
high_rated['Year'].value_counts().head(5)
# Out:
# Year
# 2016    13
# 2014    11
# 2015     8
# 2006     7
# 2009     7
# Name: count, dtype: int64

# %%
data['Rating_to_Votes'] = data['Rating'] / data['Votes']
data.nlargest(10, 'Rating_to_Votes')[['Title','Rating','Votes','Rating_to_Votes']]
# Out:
#                         Title  Rating  Votes  Rating_to_Votes
# 478            Paint It Black     8.3     61         0.136066
# 293             The Exception     7.7     96         0.080208
# 337                 Tracktown     5.9    115         0.051304
# 393             Whisky Galore     5.0    102         0.049020
# 416  The Headhunter's Calling     6.9    164         0.042073
# 538               True Crimes     7.3    198         0.036869
# 25            Paris pieds nus     6.8    222         0.030631
# 39                  5- 25- 77     7.1    241         0.029461
# 434  Let Me Make You a Martyr     6.4    223         0.028700
# 250              Bonjour Anne     4.9    178         0.027528

# %%
genre_count = data['Genre'].value_counts().head(10)
print(genre_count)
# Out:
# Genre
# Action,Adventure,Sci-Fi       50
# Comedy,Drama,Romance          30
# Drama                         29
# Drama,Romance                 27
# Animation,Adventure,Comedy    26
# Comedy                        26
# Action,Adventure,Fantasy      25
# Comedy,Drama                  24
# Comedy,Romance                22
# Crime,Drama,Thriller          18
# Name: count, dtype: int64

# %%
def movies_below_rating(df, threshold):
    return df[df['Rating'] < threshold][['Title','Rating']]

# %%
def movies_with_word(df):
    word = input("Enter a word to search in titles: ")
    print(df[df['Title'].str.contains(word, case=False)][['Title']])
movies_with_word(data)
# Out:
# Enter a word to search in titles: h
#                        Title
# 0    Guardians of the Galaxy
# 1                 Prometheus
# 5             The Great Wall
# 7                   Mindhorn
# 8         The Lost City of Z
# ..                       ...
# 992     Take Me Home Tonight
# 995     Secret in Their Eyes
# 996          Hostel: Part II
# 997   Step Up 2: The Streets
# 998             Search Party
#
# [481 rows x 1 columns]
